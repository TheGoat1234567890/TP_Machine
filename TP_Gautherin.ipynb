# %% [markdown]
# <a href="https://colab.research.google.com/github/TheGoat1234567890/TP_Machine/blob/main/TP_Gautherin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/dataset.csv")

# %%
df.head()
# Out:
#    ID gender   age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F  40.0         155        60.0       81.3             1.2
# 1   1      F  40.0         160        60.0       81.0             0.8
# 2   2      M  55.0         170        60.0       80.0             0.8
# 3   3      M  40.0         165        70.0       88.0             1.5
# 4   4      F  40.0         155        60.0       86.0             1.0
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0              1.0            1.0             1.0  ...        12.9
# 1              0.6            1.0             1.0  ...        12.7
# 2              0.8            1.0             1.0  ...        15.8
# 3              1.5            1.0             1.0  ...        14.7
# 4              1.0            1.0             1.0  ...        12.5
#
#    Urine protein  serum creatinine   AST   ALT   Gtp  oral  dental caries  \
# ...

# %%
df.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55702.000000  55696.000000  55702.000000  55696.000000  55702.000000
# mean   27850.497523     44.976569    164.648666     65.864245     82.045207
# std    16079.922395    170.266643      9.194136     12.820222      9.274171
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13925.250000     40.000000    160.000000     55.000000     76.000000
# 50%    27850.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41775.750000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000  40000.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55702.000000     55702.000000   55702.000000    55702.000000
# mean         1.012615         1.007447       1.025583        1.026139
# std          0.486833         0.485928       0.157888        0.159550
# ...

# %%
df.isnull().sum()
# Out:
# ID                     0
# gender                 0
# age                    6
# height(cm)             0
# weight(kg)             6
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
df[df["smoking"] == 1].describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  20457.000000  20456.000000  20457.000000  20456.000000  20457.000000
# mean   28090.347021     43.560813    169.435401     70.959376     84.800538
# std    16099.539463    279.616232      6.799078     12.027117      8.692757
# min        2.000000     20.000000    140.000000     35.000000     51.000000
# 25%    14147.000000     35.000000    165.000000     65.000000     79.000000
# 50%    28310.000000     40.000000    170.000000     70.000000     84.400000
# 75%    42013.000000     50.000000    175.000000     80.000000     90.000000
# max    55691.000000  40000.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    20457.000000     20457.000000   20457.000000    20457.000000
# mean         1.051718         1.047602       1.020775        1.022193
# std          0.482215         0.459022       0.142635        0.147314
# ...

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
count = df["smoking"].value_counts(dropna=False)
plt.pie(count, labels=["no-smokers", "smokers"], autopct='%.0f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_smoker=df[df["smoking"] == 1]
labels =["Male smoker", "Female smoker"]
count = [df_smoker[df_smoker['gender'] == 'M'].shape[0],df_smoker[df_smoker['gender'] == 'F'].shape[0]]

#shape pour avoir le nombre de ligne sinon il y a une erreur

plt.bar(labels , count , color=['blue', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Number of Smokers')
plt.title('Number of Smokers by Gender')
plt.show()

# %%
df[(df["smoking"] == 1) & (df["gender"] == 'M')].describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  19598.000000  19597.000000  19598.000000  19597.000000  19598.000000
# mean   28129.423002     43.437006    169.995918     71.595397     85.133595
# std    16097.595871    285.673503      6.280103     11.715688      8.515280
# min        2.000000     20.000000    145.000000     40.000000     51.000000
# 25%    14215.500000     35.000000    165.000000     65.000000     79.200000
# 50%    28336.500000     40.000000    170.000000     70.000000     85.000000
# 75%    42055.500000     50.000000    175.000000     80.000000     90.400000
# max    55691.000000  40000.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    19598.000000     19598.000000   19598.000000    19598.000000
# mean         1.058445         1.053730       1.020716        1.021941
# std          0.487042         0.463529       0.142437        0.146495
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import confusion_matrix

# %%
X = df.drop('smoking', axis = 1)
Y = df['smoking']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 0)

# %%
X.count()
# Out:
# ID                     55702
# gender                 55702
# age                    55696
# height(cm)             55702
# weight(kg)             55696
# waist(cm)              55702
# eyesight(left)         55702
# eyesight(right)        55702
# hearing(left)          55702
# hearing(right)         55702
# systolic               55702
# relaxation             55702
# fasting blood sugar    55702
# Cholesterol            55702
# triglyceride           55702
# HDL                    55702
# LDL                    55702
# hemoglobin             55702
# Urine protein          55702
# serum creatinine       55702
# AST                    55702
# ALT                    55702
# Gtp                    55702
# oral                   55702
# dental caries          55702
# tartar                 55702
# dtype: int64

# %%
knn = KNeighborsClassifier(n_neighbors=14)

# %%
knn.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-b601c265607f> in <cell line: 1>()
# ----> 1 knn.fit(X_train, Y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py in fit(self, X, y)
#     213         self._validate_params()
#     214
# --> 215         return self._fit(X, y)
#     216
#     217     def predict(self, X):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_base.py in _fit(self, X, y)
#     452         if self._get_tags()["requires_y"]:
#     453             if not isinstance(X, (KDTree, BallTree, NeighborsBase)):
# --> 454                 X, y = self._validate_data(
#     455                     X, y, accept_sparse="csr", multi_output=True, order="C"
#     456                 )
#
# ...

# %%
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns
for column in numeric_columns:
    df[column].fillna(df[column].mean(), inplace=True)

categorical_columns = df.select_dtypes(include=['object', 'category']).columns
for column in categorical_columns:
    df[column].fillna(df[column].mode()[0], inplace=True)

print(df.isnull().sum())
# Out:
# ID                     0
# gender                 0
# age                    0
# height(cm)             0
# weight(kg)             0
# waist(cm)              0
# eyesight(left)         0
# eyesight(right)        0
# hearing(left)          0
# hearing(right)         0
# systolic               0
# relaxation             0
# fasting blood sugar    0
# Cholesterol            0
# triglyceride           0
# HDL                    0
# LDL                    0
# hemoglobin             0
# Urine protein          0
# serum creatinine       0
# AST                    0
# ALT                    0
# Gtp                    0
# oral                   0
# dental caries          0
# tartar                 0
# smoking                0
# dtype: int64

# %%
columns_to_encode = ['gender', 'oral', 'tartar']
df_encoded = pd.get_dummies(df, columns=columns_to_encode)

df_encoded.describe()
# Out:
#                  ID           age    height(cm)    weight(kg)     waist(cm)  \
# count  55702.000000  55702.000000  55702.000000  55702.000000  55702.000000
# mean   27850.497523     44.976569    164.648666     65.864245     82.045207
# std    16079.922395    170.257473      9.194136     12.819532      9.274171
# min        0.000000     20.000000    130.000000     30.000000     51.000000
# 25%    13925.250000     40.000000    160.000000     55.000000     76.000000
# 50%    27850.500000     40.000000    165.000000     65.000000     82.000000
# 75%    41775.750000     55.000000    170.000000     75.000000     88.000000
# max    55691.000000  40000.000000    190.000000    135.000000    129.000000
#
#        eyesight(left)  eyesight(right)  hearing(left)  hearing(right)  \
# count    55702.000000     55702.000000   55702.000000    55702.000000
# mean         1.012615         1.007447       1.025583        1.026139
# std          0.486833         0.485928       0.157888        0.159550
# ...

# %%
X = df_encoded.drop('smoking', axis = 1)
Y = df_encoded['smoking']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state = 0)

knn = KNeighborsClassifier(n_neighbors=4
                           )

knn.fit(X_train, Y_train)

Y_pred = knn.predict(X_test)

from sklearn.metrics import confusion_matrix

confusion_mat_result = confusion_matrix(Y_pred, Y_test)

sns.heatmap(confusion_mat_result, annot=True)
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

l = LogisticRegression(max_iter=10000)
l.fit(X_train, Y_train)

Y_pred_l = l.predict(X_test)

# Évaluer les performances
accuracy_l = accuracy_score(Y_test, Y_pred_l)
precision_l = precision_score(Y_test, Y_pred_l)
recall_l = recall_score(Y_test, Y_pred_l)
f1_l = f1_score(Y_test, Y_pred_l)

print(f"Accuracy: {accuracy_l}")
print(f"Precision: {precision_l}")
print(f"Recall: {recall_l}")
print(f"F1 Score: {f1_l}")
# Out:
# Accuracy: 0.741315860335697
# Precision: 0.6540750323415265
# Recall: 0.6206727228087405
# F1 Score: 0.636936255983875

# %%
from sklearn import tree
X = [[0, 0], [1, 1]]
Y = [0, 1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X, Y)
# Out:
# DecisionTreeClassifier()
